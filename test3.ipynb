# %% [markdown]
# ## glob 生成文件列表

# %%
# !ls
# Out:
# cthouse_json
# cthouse_soup.py
# cthouse_uni.py
# etwarm_json
# etwarm_soup.py
# etwarm_uni.py
# README.md
# test_code
# test3.ipynb

# %%
import glob
import re
import json
from bs4 import BeautifulSoup

# %%
cthouse = glob.glob('./cthouse_json/*.json')

# %%
cthouse
# Out:
# ['./cthouse_json\\C0236457.json',
#  './cthouse_json\\C0236603.json',
#  './cthouse_json\\C0236970.json',
#  './cthouse_json\\C0237463.json',
#  './cthouse_json\\C0238262.json',
#  './cthouse_json\\C0238464.json',
#  './cthouse_json\\C0238586.json',
#  './cthouse_json\\C0238596.json',
#  './cthouse_json\\U0078113.json',
#  './cthouse_json\\U0145344.json',
#  './cthouse_json\\U0230681.json',
#  './cthouse_json\\U0230682.json',
#  './cthouse_json\\U0230683.json',
#  './cthouse_json\\U0232196.json',
#  './cthouse_json\\U0232264.json',
#  './cthouse_json\\U0234294.json',
#  './cthouse_json\\U0235926.json',
#  './cthouse_json\\U0236098.json',
#  './cthouse_json\\U0236454.json',
#  './cthouse_json\\U0236746.json',
#  './cthouse_json\\U0237278.json',
#  './cthouse_json\\U0237721.json',
#  './cthouse_json\\U0237787.json',
#  './cthouse_json\\U0237788.json',
#  './cthouse_json\\U0237791.json',
#  './cthouse_json\\U0238129.json',
#  './cthouse_json\\U0238130.json',
# ...

# %%
r = re.compile("\.\/cthouse_json\\\\(\w+).json")
cthouse_new = filter(r.match, cthouse)
str(cthouse_new)
# Out:
# '<filter object at 0x00000000055745F8>'

# %%
len(cthouse)
# Out:
# 30

# %%
str(re.findall('\.\/cthouse_json\\\\(\w+\.json)', cthouse[0])).lstrip('[\'').rstrip('\']')
# re.search('\.\/cthouse_json\\\\(\w+).json', cthouse[0])
# re.match('\.\/cthouse_json\\\\(\w+).json', cthouse[0])
# Out:
# 'C0236457.json'

# %%
cthouse0 = re.findall('\.\/cthouse_json\\\\(\w+\.json)', cthouse[0])
cthouse1 = re.findall('\.\/cthouse_json\\\\(\w+\.json)', cthouse[1])

# %%
cthouse0.extend(cthouse1)
cthouse0
# Out:
# ['C0236457', 'C0236603']

# %%
cthouse0 = re.findall('\.\/cthouse_json\\\\(\w+\.json)', cthouse[0])
for i in range(1, len(cthouse)):
    cthouse0.extend(re.findall('\.\/cthouse_json\\\\(\w+\.json)', cthouse[i]))

# %%
# List of file name
cthouse0
# Out:
# ['C0236457.json',
#  'C0236603.json',
#  'C0236970.json',
#  'C0237463.json',
#  'C0238262.json',
#  'C0238464.json',
#  'C0238586.json',
#  'C0238596.json',
#  'U0078113.json',
#  'U0145344.json',
#  'U0230681.json',
#  'U0230682.json',
#  'U0230683.json',
#  'U0232196.json',
#  'U0232264.json',
#  'U0234294.json',
#  'U0235926.json',
#  'U0236098.json',
#  'U0236454.json',
#  'U0236746.json',
#  'U0237278.json',
#  'U0237721.json',
#  'U0237787.json',
#  'U0237788.json',
#  'U0237791.json',
#  'U0238129.json',
#  'U0238130.json',
#  'U0238288.json',
#  'U0238436.json',
#  'U0238804.json']

# %%
'./cthouse_json/' + cthouse0[0]
# Out:
# './cthouse_json/C0236457.json'

# %%
with open('./cthouse_json/U0238804.json', "rt", encoding="utf-8") as f:
    data = json.load(f)

# %%
data["html"]
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head><meta charset="UTF-8" /><title>\r\n\t獨立套房出租-三重套房-近捷運..可來電詢問.新北市三重區泉州街38號5樓.租屋.租房子-好神租屋網\r\n</title><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /><meta name="viewport" content="width=device-width,initial-scale=1.0, maximum-scale=1, user-scalable=0" /><link rel="icon" href="../images/favicon-20160608074523567.ico" type="image/x-icon" /><link rel="shortcut icon" href="../images/favicon-20160608074523567.ico" type="image/x-icon" /><meta name="description" content="獨立套房出租，三重套房-近捷運..可來電詢問位在新北市三重區泉州街38號5樓，1房1廳1衛浴，" /><meta name="keywords" content="獨立套房出租,租房網,租屋,租屋網,新北市租屋,三重區租屋,房屋出租,好神租" /><meta property="og:title" itemprop="name" /><meta property="og:url" itemprop="url" content="http://rent.cthouse.com.tw/housing/U0238804.html" /><meta property="og:image" itemprop="image" content="http://www.cthouse.com.tw/images/fb_share01_idx.jpg" /><link rel="stylesheet" type="text/css" href="/css/vendors.css?v=20170719" media="all" /><link rel="s
# ...

# %%
soup = BeautifulSoup(data["html"], "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head><meta charset="utf-8"/><title>
# 	獨立套房出租-三重套房-近捷運..可來電詢問.新北市三重區泉州街38號5樓.租屋.租房子-好神租屋網
# ...

# %%
def readData(fileName):
    try:
        with open('./cthouse_json/' + fileName, "rt", encoding="utf-8") as f:
            data = json.load(f)
            return data
    except FileNotFoundError as e:
        print(e)

# %%
readData(cthouse0[0])["url"]
# Out:
# 'http://rent.cthouse.com.tw/housing/C0236457.html'

# %%
soup = BeautifulSoup(readData(cthouse0[0])["html"], "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head><meta charset="utf-8"/><title>
# 	雅房出租-民權街雅房出租..租屋.租房子-好神租屋網
# ...

# %% [markdown]
# ***

# %%
etwarm = glob.glob('./etwarm_json/*.json')

# %%
etwarm
# Out:
# ['./etwarm_json\\178343.json',
#  './etwarm_json\\178378.json',
#  './etwarm_json\\178450.json',
#  './etwarm_json\\178501.json',
#  './etwarm_json\\178707.json',
#  './etwarm_json\\179181.json',
#  './etwarm_json\\179257.json',
#  './etwarm_json\\179368.json',
#  './etwarm_json\\179476.json',
#  './etwarm_json\\179529.json',
#  './etwarm_json\\179587.json',
#  './etwarm_json\\179730.json',
#  './etwarm_json\\179791.json',
#  './etwarm_json\\179908.json',
#  './etwarm_json\\179952.json',
#  './etwarm_json\\180135.json',
#  './etwarm_json\\180273.json',
#  './etwarm_json\\180510.json',
#  './etwarm_json\\180534.json',
#  './etwarm_json\\180535.json',
#  './etwarm_json\\180564.json',
#  './etwarm_json\\180607.json',
#  './etwarm_json\\180635.json',
#  './etwarm_json\\180762.json',
#  './etwarm_json\\180765.json',
#  './etwarm_json\\180778.json',
#  './etwarm_json\\180916.json',
#  './etwarm_json\\180984.json',
#  './etwarm_json\\180985.json',
#  './etwarm_json\\181055.json',
# ...

# %%
str(re.findall('\.\/etwarm_json\\\\(\w+\.json)', etwarm[0])).lstrip('[\'').rstrip('\']')
# Out:
# '178343.json'

# %%
etwarm0 = re.findall('\.\/etwarm_json\\\\(\w+\.json)', etwarm[0])
for i in range(1, len(etwarm)):
    etwarm0.extend(re.findall('\.\/etwarm_json\\\\(\w+\.json)', etwarm[i]))

# %%
# List of file name
etwarm0
# Out:
# ['178343.json',
#  '178378.json',
#  '178450.json',
#  '178501.json',
#  '178707.json',
#  '179181.json',
#  '179257.json',
#  '179368.json',
#  '179476.json',
#  '179529.json',
#  '179587.json',
#  '179730.json',
#  '179791.json',
#  '179908.json',
#  '179952.json',
#  '180135.json',
#  '180273.json',
#  '180510.json',
#  '180534.json',
#  '180535.json',
#  '180564.json',
#  '180607.json',
#  '180635.json',
#  '180762.json',
#  '180765.json',
#  '180778.json',
#  '180916.json',
#  '180984.json',
#  '180985.json',
#  '181055.json',
#  '181116.json',
#  '181139.json',
#  '181144.json']
